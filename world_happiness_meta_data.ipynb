# %%
import os
import pandas as pd 
import numpy as np

import missingno as msno

import utils
import config

# %%
year_to_data = utils.export_data('data')

# %%
year_to_data.keys()
# Out:
# dict_keys([2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022])

# %%
for year, data in year_to_data.items():
    print(f'{year}: {data.columns}')
# Out:
# 2015: Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')
# 2016: Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')
# 2017: Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')
# 2018: Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
# ...

# %%
msno.matrix(year_to_data.get(2015))
# Out:
# <AxesSubplot:>

# %%
msno.matrix(year_to_data.get(2022))
# Out:
# <AxesSubplot:>

# %%
# 12 columns 
### Here there is standart error 
year_to_data.get(2015).columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# 13 columns
## Lower Confidence Interval and Upper Confidence Interval
year_to_data.get(2016).columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
# 12 columns
year_to_data.get(2017).columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
# 9 columns
year_to_data.get(2018).columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
year_to_data.get(2019).columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
year_to_data.get(2020).columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
year_to_data.get(2021).columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
year_to_data.get(2022).columns
# Out:
# Index(['RANK', 'Country', 'Happiness score', 'Whisker-high', 'Whisker-low',
#        'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption'],
#       dtype='object')

# %% [markdown]
# List countries presented in the 2015 table but were absent in the 2016 table.
# All these countries are from Africa, the most intresting note is Oman with realtevly high index disappear from the data

# %%
year_to_data.get(2015)[~year_to_data.get(2015)['Country'].isin(year_to_data.get(2016)['Country'])][['Country', 'Happiness Score', 'Region', 'Happiness Rank']]
# Out:
#                       Country  Happiness Score  \
# 21                       Oman            6.853
# 90          Somaliland region            5.057
# 93                 Mozambique            4.971
# 96                    Lesotho            4.898
# 100                 Swaziland            4.867
# 125                  Djibouti            4.369
# 147  Central African Republic            3.678
#
#                               Region  Happiness Rank
# 21   Middle East and Northern Africa              22
# 90                Sub-Saharan Africa              91
# 93                Sub-Saharan Africa              94
# 96                Sub-Saharan Africa              97
# 100               Sub-Saharan Africa             101
# 125               Sub-Saharan Africa             126
# 147               Sub-Saharan Africa             148

# %%
uncommon_countries_2015_2016 = list(year_to_data.get(2015)[~year_to_data.get(2015)['Country'].isin(year_to_data.get(2016)['Country'])]['Country'])

# %%
uncommon_countries_2015_2016
# Out:
# ['Oman',
#  'Somaliland region',
#  'Mozambique',
#  'Lesotho',
#  'Swaziland',
#  'Djibouti',
#  'Central African Republic']

# %%
for year, data in year_to_data.items():
    data['year'] = year

# %%
# Only 2020 and 2021 dataframe does not have rank column,
# thus add it manually
year_to_data.get(2020)['RANK'] = year_to_data.get(2020).index + 1
year_to_data.get(2021)['RANK'] = year_to_data.get(2021).index + 1

# %%
year_to_data = utils.bring_to_common_column_name(year_to_data, config.year_to_rank_column_name, "rank")
year_to_data = utils.bring_to_common_column_name(year_to_data, config.year_to_happiness_score_column_name, "happiness_score")
year_to_data = utils.bring_to_common_column_name(year_to_data, config.year_to_country_column_name, "Country")

# %%
utils.create_bump_chart(year_to_data)
